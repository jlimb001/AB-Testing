# %%
import pandas as pd

# %%
time_spent_df = pd.read_csv('index.csv')
time_spent_df
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70589    7993686             4.0              56.0      38.5     U        3.0
# 70590    8981690            12.0             148.0      31.0     M        2.0
# 70591     333913            16.0             198.0      61.5     F        2.0
# 70592    1573142            21.0             255.0      68.0     M        3.0
# 70593    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
time_spent_df['start'] = (time_spent_df['process_step'] == 'start').astype(int)
time_spent_df['step_1'] = (time_spent_df['process_step'] == 'step_1').astype(int)
time_spent_df['step_2'] = (time_spent_df['process_step'] == 'step_2').astype(int)
time_spent_df['step_3'] = (time_spent_df['process_step'] == 'step_3').astype(int)
time_spent_df['confirm'] = (time_spent_df['process_step'] == 'confirm').astype(int)

# %%
time_spent_df.head(20)
# Out:
#     client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0      836976             6.0              73.0      60.5     U        2.0
# 1     2304905             7.0              94.0      58.0     U        2.0
# 2     1439522             5.0              64.0      32.0     U        2.0
# 3     1562045            16.0             198.0      49.0     M        2.0
# 4     5126305            12.0             145.0      33.0     F        2.0
# 5     3727881             5.0              71.0      30.5     U        2.0
# 6      272934             5.0              66.0      58.5     U        2.0
# 7      388801            30.0             361.0      57.5     M        5.0
# 8      285619            30.0             369.0      67.5     M        2.0
# 9     8198645            15.0             189.0      54.5     F        2.0
# 10    8368822             8.0             100.0      34.5     U        2.0
# ...

# %%
time_spent_df.to_csv('process_step.csv', index=False)

# %%
filtered_df = time_spent_df[time_spent_df[st]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 filtered_df = time_spent_df[time_spent_df[st]]
#
# NameError: name 'st' is not defined

# %%
time_spent_df = time_spent_df.drop(time_spent_df.columns[[1,2, 3, 4, 5, 6, 9, 10, 11, 12 ]], axis=1)
time_spent_df
# Out:
#         client_id  calls_6_mnth  logons_6_mnth num_accts_status bal_status  \
# 0         6265388           5.0            8.0         Provided   Provided
# 1         6265388           5.0            8.0         Provided   Provided
# 2         6265388           5.0            8.0         Provided   Provided
# 3         6265388           5.0            8.0         Provided   Provided
# 4         6265388           5.0            8.0         Provided   Provided
# ...           ...           ...            ...              ...        ...
# 352080    9998750           1.0            1.0         Provided   Provided
# 352081    9998820           5.0            5.0         Provided   Provided
# 352082    9999150           6.0            9.0         Provided   Provided
# 352083    9999626           6.0            9.0         Provided   Provided
# 352084    9999832           1.0            4.0         Provided   Provided
#
#        calls_6_mnth_status logons_6_mnth_status Variation  \
# ...
